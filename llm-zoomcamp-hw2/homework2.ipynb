# %%
from embedder import Embedder

embedder = Embedder('models/Xenova/all-MiniLM-L6-v2')
query = 'How does approximate nearest neighbor search work?'
v = embedder.encode(query)
print('v[0] =', v[0])
print('length =', len(v))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from embedder import Embedder
#       2
#       3 embedder = Embedder('models/Xenova/all-MiniLM-L6-v2')
#       4 query = 'How does approximate nearest neighbor search work?'
#
# File /workspaces/module_2_llm/llm-zoomcamp-hw2/embedder.py:2
#       1 import numpy as np
# ----> 2 import onnxruntime as ort
#       3 from tokenizers import Tokenizer
#       4 from pathlib import Path
#
# ModuleNotFoundError: No module named 'onnxruntime'
